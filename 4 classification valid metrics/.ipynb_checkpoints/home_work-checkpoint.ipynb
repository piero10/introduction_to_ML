# %% [markdown]
# ### Домашнее задание
#
# данные находятся в  home_work_data/data.csv
#
# 1. Загрузите данные, проведите EDA (как на предыдущем уроке)
# 2. Выполни препроцессинг данных, все обязательные шаги
# 3. Подумай как бы ты решал эту задачу бинарной классификации, какую метрику ты бы выбрал, обоснуй свое мнение.
# 4. Построй логику поиска порога, проинтепретируйте, проилюстрируйте как изменение порога влияет на расположение границы принятия решений, используй ROC и среднее геометрическое между TPR и FPR как критерий оптимизации.
# 6. При оптимизации порога по PR-кривой используйте другую F-метрику - сначала с преимуществом precision, а затем - с превалированием recall. Изобразите получившиеся пороги на графике. Проанализируйте метрики получившихся моделей.
# 7. Подумай как применить F-beta метрику
