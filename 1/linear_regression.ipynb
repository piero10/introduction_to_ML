# %% [markdown]
# ## Линейная регрессия
# Познакомиться с основными понятиями задачи регрессии и метода градиентного спуска.

# %% [markdown]
# ### Содержание работы
#
# 1. Загрузить данные из текстовых файлов.
# 2. Создать и построить модель линейной регрессии с использованием метода градиентного спуска.
# 3. Оценить на графике качество построенной модели.
# 4. Построить кривые обучения.

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# C:\conda\envs\gaz\python.exe
# 3.13.0 | packaged by Anaconda, Inc. | (main, Oct  7 2024, 21:21:52) [MSC v.1929 64 bit (AMD64)]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# 'C:\\ml_introduction'

# %%
x = pd.read_csv('data/x.csv')['0']
y = pd.read_csv('data/y.csv')['0']

# %% [markdown]
# Посмотрим формат файла с данными - состав и названия полей:

# %%
x.head()
# Out:
# 0    1.462108
# 1    1.133769
# 2   -2.301539
# 3    1.744812
# 4    0.042214
# Name: 0, dtype: float64

# %%
y.head()
# Out:
# 0    101.159902
# 1     78.442913
# 2   -159.238195
# 3    120.719533
# 4      2.920673
# Name: 0, dtype: float64

# %%
plt.figure()
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### Построим модель линейной регрессии своими руками

# %%
class Model(object):
    """Модель парной линейной регрессии"""
    def __init__(self):
        self.b0 = 0
        self.b1 = 0

    def predict(self, x):
        return self.b0 + self.b1 * x

    def error(self, X, Y):    
        return sum((self.predict(X) - Y)**2) / (2 * len(X))

    def fit(self, X, Y):  
        alpha = 0.1
        dJ0 = sum(self.predict(X) - Y) / len(X)
        dJ1 = sum((self.predict(X) - Y) * X) / len(X)
        self.b0 -= alpha * dJ0
        self.b1 -= alpha * dJ1

# %% [markdown]
# ### Исследуем работу линейной регресси по шагам

# %%
hyp = Model()
print(hyp.predict(0))
print(hyp.predict(100))
J = hyp.error(x, y)
print("initial error:", J)
# Out:
# 0
# 0
# initial error: 2937.6446095153397

# %%
X0 = np.linspace(-3, 2, 100)
Y0 = hyp.predict(X0)
plt.figure()
plt.scatter(x, y)
plt.plot(X0, Y0, 'r')
plt.show()

# %%
hyp.fit(x, y)
J = hyp.error(x, y)
print("error after gradient descent:", J)
# Out:
# error after gradient descent: 2253.745680891855

# %%
X0 = np.linspace(-3, 2, 100)
Y0 = hyp.predict(X0)
plt.figure()
plt.scatter(x, y)
plt.plot(X0, Y0, 'r')
plt.show()

# %% [markdown]
# ### Что дальше?
# дальнейшее оставляем на домашнее задание
