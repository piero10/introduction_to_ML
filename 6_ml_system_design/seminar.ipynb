# %% [markdown]
# ### Цель
# - Знакомство со стандартным пайпланом реализации модели в продакшн
# - Изучение стандартныйх фреймворков для продуктивизации моделей
#     - FastAPI
#         - get
#         - port
#         - endpoint
#     - Swagger
#         - docs
#         - выполнение запроса из swagger
# - Построение и сериализация модели
# - Изучение стандартныйх фреймворков:
#     - MLFlow
#     - Streamlit

# %% [markdown]
# ## План работы
# ### 6_ml_server_hand_made
#     - Смотрим requirements
#     - Строим модель
#         - смотрим что модель сохранилась
#     - Изучаем app.py
#         - ...
#     - запускаем
#     - Изучаем FastAPI
#         - запускаем FastAPI сервер
#             - uvicorn app:app --host 127.0.0.1 --port 8000 --reload
#         - смотрим root страницу проекта
#             - http://127.0.0.1:8000/
#         - порт лучше ставить другой не по умолчанию
#
#     - Изучаем Swagger
#         - http://127.0.0.1:8000/docs
#         - видим 2 endpoints
#         - схема совпадает с нашей pydantic моделью
#         - пример в swagger
#         - пример в post
#         - выполняем какой-то запрос, видим, что результат поменялся, в зависимости от возраста
#
#     - Дергаем сервер из браузера
#         - http://127.0.0.2:8008/predict_batch?age=29&age=22&fare=35.5&fare=7.25&sex=female&sex=male&pclass=Second&pclass=Third&embarked=S&embarked=C
#         - http://127.0.0.2:8008/predict_simple?age=29&fare=35.5&sex=female&pclass=Second&embarked=S
#         - разбираемся в запросе
#     - отмечаем что строка запроса читаема!!!
#     - Реализуем клиент который будет обращаться к серверу
#         - для отправки запроса для одного клиента
#         - для множества клиентов
#         - работаем с клиентом с дебагером
#
# - Запускаем сервер из-под дебагера
#     - app_unicorn
#         - http://127.0.0.2:8008/

# %% [markdown]
# ### streamlit
# - изучаем код сервера
# - рассказ про streamlit
# - запускаем:
#     - streamlit run app.py

# %% [markdown]
# ## mlflow
# - выбираем окружение mlflow
# - делаем сервинг модели
#     - mlflow models serve -m "runs:/df3eae37fb8c4f01bc227ac9fbc2d4cd/model_rf" -p 8000 --no-conda
#     - mlflow models serve -m "runs:/df3eae37fb8c4f01bc227ac9fbc2d4cd/one_more_model" -p 8000 --no-conda
#     - вызываем модель из curl
#     - curl -X POST -H "Content-Type: application/json" -d "{\"dataframe_split\": {\"columns\": [\"Pclass\",\"Sex\",\"Age\",\"Fare\",\"Embarked\"], \"data\": [[3,1,22,7.25,0]]}}" http://127.0.0.1:8000/invocations
#     - замечание:
#         - MLflow поднимает REST API сервер, а не обычный web-сайт. То есть сервер ожидает JSON-запросы типа POST, а не открытие HTML-страницы.
# - загружаем морду
#     - mlflow ui
#
# - MLFlow - платформа, не программа
# - Суппорт от выдвижения гипотезы до реализации
# - подбирать гиперпараметры
# - tracjing Хранит наботы гиперпараметров и скоры
# - model regestry - хранит обученные модели в виде готового объекта
# - projects. хранит код модели, препроцессинга
#
# Сценарии использования:
# - трекинг экспериментов
# - выбор модели
# - мониторинг модели
# - коллоборация

# %%
mlflow server --backend-store-uri sqlite:///mlflow.db --default-artifact-root ./mlruns --host 127.0.0.1  --port 5050
