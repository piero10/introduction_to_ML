# %% [markdown]
# ## Домашнее задание EDA

# %% [markdown]
# ### Что Требуется сделать
# - Проанализировать данные, порассуждать над ними, построить графики, и др
# - Выполнить все шаги препроцессинга
# - Построить модель, обучить модель минимизировать f1-меру
# - Провести над ней кроссвалидацию
# - Продемонстрировать эффективную работу с данными в pandas (данных тут относительно много > 100mb)

# %%
import pandas as pd

df = pd.read_csv('data_home_task/train.csv')
df.head()
# Out:
#    id class  cap-diameter cap-shape cap-surface cap-color  \
# 0   0     e          8.80         f           s         u
# 1   1     p          4.51         x           h         o
# 2   2     e          6.94         f           s         b
# 3   3     e          3.88         f           y         g
# 4   4     e          5.85         x           l         w
#
#   does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# 0                    f               a            c          w  ...
# 1                    f               a            c          n  ...
# 2                    f               x            c          w  ...
# 3                    f               s          NaN          g  ...
# 4                    f               d          NaN          w  ...
#
#    stem-root  stem-surface stem-color veil-type veil-color has-ring ring-type  \
# 0        NaN           NaN          w       NaN        NaN        f         f
# ...

# %% [markdown]
# Описание данных:
# class - это таргет метка (e - edible, p - poisoned)
