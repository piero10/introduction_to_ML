# %% [markdown]
# # Домашняя работа по теме "Обучение без учителя"
#
# 1. Реализуйте алгоритм кластеризации, руками, например (AgglomerativeClustering)[https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html]
# 2. Реализация должна быть в виде класса с главные методами:
#     - __ init __
#     - fit
#     - fit_transform
#     - fit_predict
#
# ---
#
# 3. Должна быть возможность подать на вход dataframe с numerical колонками
# 4. реализовать нормализацию внутри fit - fit(normalize=True)
# 5. Реализуйте критерии останова - по максимальному ко-ву итераций, по критерию близости (для k-means - не более N Объектов поменяли кластер, и др.)
# 6. Сделайте несколько примеров применения вашего кластеризатора, визуализируйте результаты вашей работы
